# %%
from ultralytics import YOLO
from PIL import Image
import matplotlib.pyplot as plt
model = YOLO("yolov8n.pt")
results = model("image.png")

# Convert results to an image with bounding boxes
img_with_boxes = results[0].plot()

# Display the image
plt.imshow(img_with_boxes)
plt.axis("off")  # Hide axes for better visualization
plt.show()
# Out:
# image 1/1 /home/joaocbranco/projects/habitat-meta/experiments/outputs/image.png: 640x640 1 chair, 7.0ms
# Speed: 3.3ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
